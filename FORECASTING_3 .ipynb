# %%
#%matplotlib inline

# %%
import datetime
from pandas.core.indexes.datetimes import date
import pandas as pd
import numpy as np
import scipy as sp
import statsmodels as sm
import sklearn as sl

# !pip install pmdarima

import pmdarima as pm
from pmdarima.arima import auto_arima
from pmdarima.model_selection import train_test_split
from pmdarima.pipeline import Pipeline
from pmdarima.preprocessing import BoxCoxEndogTransformer
import pickle

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import datetime as dt

import statsmodels.formula.api as smf
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
import statsmodels.stats.multicomp as multi

from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
import statsmodels.stats.multicomp as mutti

from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.compat.scipy import _next_regular

import warnings
warnings.filterwarnings ("ignore")

from sklearn.decomposition import PCA
from scipy.stats import pearsonr
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pmdarima in /usr/local/lib/python3.7/dist-packages (2.0.1)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.29.32)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (57.4.0)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.3.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.2.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.7.3)
# Requirement already satisfied: statsmodels>=0.13.2 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.13.5)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.21.6)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2022.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22->pmdarima) (3.1.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.7/dist-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.7/dist-packages (from statsmodels>=0.13.2->pmdarima) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=21.3->statsmodels>=0.13.2->pmdarima) (3.0.9)

# %%
url = 'https://raw.githubusercontent.com/josealfonsocr/Proyecto-Skills/main/Walmart_Store_sales.csv'
df = pd.read_csv (url)
print('Shape of data',df.shape)
df.head(15)
# Out:
# Shape of data (6435, 8)
#     Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0       1  05-02-2010    1643690.90             0        42.31       2.572
# 1       1  12-02-2010    1641957.44             1        38.51       2.548
# 2       1  19-02-2010    1611968.17             0        39.93       2.514
# 3       1  26-02-2010    1409727.59             0        46.63       2.561
# 4       1  05-03-2010    1554806.68             0        46.50       2.625
# 5       1  12-03-2010    1439541.59             0        57.79       2.667
# 6       1  19-03-2010    1472515.79             0        54.58       2.720
# 7       1  26-03-2010    1404429.92             0        51.45       2.732
# 8       1  02-04-2010    1594968.28             0        62.27       2.719
# 9       1  09-04-2010    1545418.53             0        65.86       2.770
# 10      1  16-04-2010    1466058.28             0        66.32       2.808
# 11      1  23-04-2010    1391256.12             0        64.84       2.795
# 12      1  30-04-2010    1425100.71             0        67.41       2.780
# 13      1  07-05-2010    1603955.12             0        72.55       2.835
# 14      1  14-05-2010    1494251.50             0        74.78       2.854
#
#            CPI  Unemployment
# 0   211.096358         8.106
# 1   211.242170         8.106
# 2   211.289143         8.106
# 3   211.319643         8.106
# 4   211.350143         8.106
# 5   211.380643         8.106
# 6   211.215635         8.106
# 7   211.018042         8.106
# 8   210.820450         7.808
# 9   210.622857         7.808
# 10  210.488700         7.808
# 11  210.439123         7.808
# 12  210.389546         7.808
# 13  210.339968         7.808
# 14  210.337426         7.808

# %%
df.head()
#se ven los encabezados
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
#pd.options.display.float_format='{:,.2f}'.format
#cambiar el punto flotante

# %%
df.describe()
# Out:
#          Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price      CPI  \
# count 6,435.00      6,435.00      6,435.00     6,435.00    6,435.00 6,435.00
# mean     23.00  1,046,964.88          0.07        60.66        3.36   171.58
# std      12.99    564,366.62          0.26        18.44        0.46    39.36
# min       1.00    209,986.25          0.00        -2.06        2.47   126.06
# 25%      12.00    553,350.10          0.00        47.46        2.93   131.74
# 50%      23.00    960,746.04          0.00        62.67        3.44   182.62
# 75%      34.00  1,420,158.66          0.00        74.94        3.73   212.74
# max      45.00  3,818,686.45          1.00       100.14        4.47   227.23
#
#        Unemployment
# count      6,435.00
# mean           8.00
# std            1.88
# min            3.88
# 25%            6.89
# 50%            7.87
# 75%            8.62
# max           14.31

# %%
df.info()
#tipo de variables
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
df["Date"]=pd.to_datetime(df["Date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   datetime64[ns]
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(2)
# memory usage: 402.3 KB

# %%
df.Date.describe()
# Out:
# count                    6435
# unique                    143
# top       2010-05-02 00:00:00
# freq                       45
# first     2010-01-10 00:00:00
# last      2012-12-10 00:00:00
# Name: Date, dtype: object

# %%
df["Year"]= df['Date'].dt.year
df["Quarter"]= df['Date'].dt.quarter
df["Month"]= df['Date'].dt.month
df["Week"]= df['Date'].dt.week
df["Day"]= df['Date'].dt.day
df
#desglosar la fecha
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-05-02    1643690.90             0        42.31       2.572
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-05-03    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-05-10     733455.07             0        64.89       3.985
# 6432     45 2012-12-10     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment  Year  Quarter  Month  Week  Day
# 0     211.096358         8.106  2010        2      5    17    2
# 1     211.242170         8.106  2010        4     12    48    2
# 2     211.289143         8.106  2010        1      2     7   19
# 3     211.319643         8.106  2010        1      2     8   26
# 4     211.350143         8.106  2010        2      5    18    3
# ...          ...           ...   ...      ...    ...   ...  ...
# 6430  192.013558         8.684  2012        3      9    39   28
# 6431  192.170412         8.667  2012        2      5    19   10
# 6432  192.327265         8.667  2012        4     12    50   10
# 6433  192.330854         8.667  2012        4     10    42   19
# 6434  192.308899         8.667  2012        4     10    43   26
#
# [6435 rows x 13 columns]

# %%
group=df.groupby("Store").sum("Weekly_Sales")
group.reset_index(level=0, inplace=True)
group["Weekly_Sales"]=(group["Weekly_Sales"])
pd.options.display.float_format='{:,.2f}'.format
group
#"agrupar por tienda y por venta semanal
# Out:
#     Store   Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price       CPI  \
# 0       1 222,402,808.85            10     9,767.87      460.42 30,887.56
# 1       2 275,382,440.98            10     9,754.94      460.42 30,837.42
# 2       3  57,586,735.07            10    10,215.09      460.42 31,372.99
# 3       4 299,543,953.38            10     8,902.23      460.03 18,401.19
# 4       5  45,475,688.90            10     9,925.65      460.42 30,968.88
# 5       6 223,756,130.64            10     9,967.10      460.42 31,110.11
# 6       7  81,598,275.14            10     5,680.00      463.54 27,693.99
# 7       8 129,951,181.13            10     8,939.50      460.42 31,379.78
# 8       9  77,789,218.99            10     9,691.85      460.42 31,406.62
# 9      10 271,617,713.89            10    10,330.49      511.36 18,401.19
# 10     11 193,962,786.80            10    10,364.75      460.42 31,372.99
# 11     12 144,287,230.15            10    10,047.58      515.72 18,401.19
# 12     13 286,517,703.80            10     7,678.69      469.92 18,401.19
# 13     14 288,999,911.34            10     8,264.11      488.72 26,638.85
# 14     15  89,133,683.92            10     7,412.24      511.70 19,318.24
# 15     16  74,252,425.40            10     6,439.30      463.54 27,693.99
# 16     17 127,782,138.83            10     6,633.37      469.92 18,401.19
# 17     18 155,114,734.21            10     7,632.09      492.17 19,318.24
# 18     19 206,634,862.10            10     7,478.19      511.70 19,318.24
# 19     20 301,397,792.46            10     7,929.55      488.72 29,892.45
# 20     21 108,117,878.92            10     9,845.21      460.42 30,837.42
# 21     22 147,075,648.57            10     7,850.29      492.17 19,878.61
# 22     23 198,750,617.85            10     6,979.13      492.17 19,318.24
# 23     24 194,016,021.28            10     7,726.29      511.70 19,318.24
# 24     25 101,061,179.17            10     7,455.79      488.72 29,892.45
# 25     26 143,416,393.79            10     6,243.13      492.17 19,318.24
# 26     27 253,855,916.88            10     8,195.49      511.70 19,878.61
# 27     28 189,263,680.58            10    10,047.58      515.72 18,401.19
# 28     29  77,141,554.31            10     7,850.29      492.17 19,318.24
# 29     30  62,716,885.12            10     9,845.21      460.42 30,837.42
# 30     31 199,613,905.50            10     9,845.21      460.42 30,837.42
# 31     32 166,819,246.16            10     7,542.90      463.54 27,693.99
# 32     33  37,160,221.96            10    10,972.13      511.36 18,401.19
# 33     34 138,249,763.00            10     8,364.91      460.03 18,401.19
# 34     35 131,520,672.08            10     8,195.49      488.72 19,878.61
# 35     36  53,412,214.97            10    10,175.93      458.20 30,706.26
# 36     37  74,202,740.32            10    10,175.93      460.42 30,706.26
# 37     38  55,159,626.42            10    10,047.58      515.72 18,401.19
# 38     39 207,445,542.47            10    10,095.42      460.42 30,706.26
# 39     40 137,870,309.79            10     6,817.46      492.17 19,318.24
# 40     41 181,341,934.89            10     6,922.68      463.54 27,693.99
# 41     42  79,565,752.43            10    10,330.49      511.36 18,401.19
# 42     43  90,565,435.41            10     9,849.51      460.42 29,706.13
# 43     44  43,293,087.84            10     7,678.69      469.92 18,401.19
# 44     45 112,395,341.42            10     8,264.11      488.72 26,638.85
#
#     Unemployment    Year  Quarter  Month  Week   Day
# 0       1,088.29  287568      357    926  3718  2238
# 1       1,090.21  287568      357    926  3718  2238
# 2       1,026.31  287568      357    926  3718  2238
# 3         852.95  287568      357    926  3718  2238
# 4         900.24  287568      357    926  3718  2238
# 5         944.79  287568      357    926  3718  2238
# 6       1,227.76  287568      357    926  3718  2238
# 7         871.13  287568      357    926  3718  2238
# 8         872.28  287568      357    926  3718  2238
# 9       1,195.90  287568      357    926  3718  2238
# 10      1,026.31  287568      357    926  3718  2238
# 11      1,875.66  287568      357    926  3718  2238
# 12      1,001.26  287568      357    926  3718  2238
# 13      1,236.77  287568      357    926  3718  2238
# 14      1,143.46  287568      357    926  3718  2238
# 15        926.35  287568      357    926  3718  2238
# 16        936.56  287568      357    926  3718  2238
# 17      1,263.88  287568      357    926  3718  2238
# 18      1,143.46  287568      357    926  3718  2238
# 19      1,054.11  287568      357    926  3718  2238
# 20      1,090.21  287568      357    926  3718  2238
# 21      1,153.92  287568      357    926  3718  2238
# 22        685.83  287568      357    926  3718  2238
# 23      1,207.92  287568      357    926  3718  2238
# 24      1,054.11  287568      357    926  3718  2238
# 25      1,125.71  287568      357    926  3718  2238
# 26      1,144.25  287568      357    926  3718  2238
# 27      1,875.66  287568      357    926  3718  2238
# 28      1,402.31  287568      357    926  3718  2238
# 29      1,090.21  287568      357    926  3718  2238
# 30      1,090.21  287568      357    926  3718  2238
# 31      1,227.76  287568      357    926  3718  2238
# 32      1,220.24  287568      357    926  3718  2238
# 33      1,420.68  287568      357    926  3718  2238
# 34      1,256.77  287568      357    926  3718  2238
# 35      1,125.27  287568      357    926  3718  2238
# 36      1,125.27  287568      357    926  3718  2238
# 37      1,875.66  287568      357    926  3718  2238
# 38      1,125.27  287568      357    926  3718  2238
# 39        685.83  287568      357    926  3718  2238
# 40        997.19  287568      357    926  3718  2238
# 41      1,195.90  287568      357    926  3718  2238
# 42      1,420.68  287568      357    926  3718  2238
# 43        963.19  287568      357    926  3718  2238
# 44      1,236.77  287568      357    926  3718  2238

# %%
sort_WeeklySales=group.sort_values('Weekly_Sales', ascending=False)
sort_WeeklySales
# Out:
#     Store   Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price       CPI  \
# 19     20 301,397,792.46            10     7,929.55      488.72 29,892.45
# 3       4 299,543,953.38            10     8,902.23      460.03 18,401.19
# 13     14 288,999,911.34            10     8,264.11      488.72 26,638.85
# 12     13 286,517,703.80            10     7,678.69      469.92 18,401.19
# 1       2 275,382,440.98            10     9,754.94      460.42 30,837.42
# 9      10 271,617,713.89            10    10,330.49      511.36 18,401.19
# 26     27 253,855,916.88            10     8,195.49      511.70 19,878.61
# 5       6 223,756,130.64            10     9,967.10      460.42 31,110.11
# 0       1 222,402,808.85            10     9,767.87      460.42 30,887.56
# 38     39 207,445,542.47            10    10,095.42      460.42 30,706.26
# 18     19 206,634,862.10            10     7,478.19      511.70 19,318.24
# 30     31 199,613,905.50            10     9,845.21      460.42 30,837.42
# 22     23 198,750,617.85            10     6,979.13      492.17 19,318.24
# 23     24 194,016,021.28            10     7,726.29      511.70 19,318.24
# 10     11 193,962,786.80            10    10,364.75      460.42 31,372.99
# 27     28 189,263,680.58            10    10,047.58      515.72 18,401.19
# 40     41 181,341,934.89            10     6,922.68      463.54 27,693.99
# 31     32 166,819,246.16            10     7,542.90      463.54 27,693.99
# 17     18 155,114,734.21            10     7,632.09      492.17 19,318.24
# 21     22 147,075,648.57            10     7,850.29      492.17 19,878.61
# 11     12 144,287,230.15            10    10,047.58      515.72 18,401.19
# 25     26 143,416,393.79            10     6,243.13      492.17 19,318.24
# 33     34 138,249,763.00            10     8,364.91      460.03 18,401.19
# 39     40 137,870,309.79            10     6,817.46      492.17 19,318.24
# 34     35 131,520,672.08            10     8,195.49      488.72 19,878.61
# 7       8 129,951,181.13            10     8,939.50      460.42 31,379.78
# 16     17 127,782,138.83            10     6,633.37      469.92 18,401.19
# 44     45 112,395,341.42            10     8,264.11      488.72 26,638.85
# 20     21 108,117,878.92            10     9,845.21      460.42 30,837.42
# 24     25 101,061,179.17            10     7,455.79      488.72 29,892.45
# 42     43  90,565,435.41            10     9,849.51      460.42 29,706.13
# 14     15  89,133,683.92            10     7,412.24      511.70 19,318.24
# 6       7  81,598,275.14            10     5,680.00      463.54 27,693.99
# 41     42  79,565,752.43            10    10,330.49      511.36 18,401.19
# 8       9  77,789,218.99            10     9,691.85      460.42 31,406.62
# 28     29  77,141,554.31            10     7,850.29      492.17 19,318.24
# 15     16  74,252,425.40            10     6,439.30      463.54 27,693.99
# 36     37  74,202,740.32            10    10,175.93      460.42 30,706.26
# 29     30  62,716,885.12            10     9,845.21      460.42 30,837.42
# 2       3  57,586,735.07            10    10,215.09      460.42 31,372.99
# 37     38  55,159,626.42            10    10,047.58      515.72 18,401.19
# 35     36  53,412,214.97            10    10,175.93      458.20 30,706.26
# 4       5  45,475,688.90            10     9,925.65      460.42 30,968.88
# 43     44  43,293,087.84            10     7,678.69      469.92 18,401.19
# 32     33  37,160,221.96            10    10,972.13      511.36 18,401.19
#
#     Unemployment    Year  Quarter  Month  Week   Day
# 19      1,054.11  287568      357    926  3718  2238
# 3         852.95  287568      357    926  3718  2238
# 13      1,236.77  287568      357    926  3718  2238
# 12      1,001.26  287568      357    926  3718  2238
# 1       1,090.21  287568      357    926  3718  2238
# 9       1,195.90  287568      357    926  3718  2238
# 26      1,144.25  287568      357    926  3718  2238
# 5         944.79  287568      357    926  3718  2238
# 0       1,088.29  287568      357    926  3718  2238
# 38      1,125.27  287568      357    926  3718  2238
# 18      1,143.46  287568      357    926  3718  2238
# 30      1,090.21  287568      357    926  3718  2238
# 22        685.83  287568      357    926  3718  2238
# 23      1,207.92  287568      357    926  3718  2238
# 10      1,026.31  287568      357    926  3718  2238
# 27      1,875.66  287568      357    926  3718  2238
# 40        997.19  287568      357    926  3718  2238
# 31      1,227.76  287568      357    926  3718  2238
# 17      1,263.88  287568      357    926  3718  2238
# 21      1,153.92  287568      357    926  3718  2238
# 11      1,875.66  287568      357    926  3718  2238
# 25      1,125.71  287568      357    926  3718  2238
# 33      1,420.68  287568      357    926  3718  2238
# 39        685.83  287568      357    926  3718  2238
# 34      1,256.77  287568      357    926  3718  2238
# 7         871.13  287568      357    926  3718  2238
# 16        936.56  287568      357    926  3718  2238
# 44      1,236.77  287568      357    926  3718  2238
# 20      1,090.21  287568      357    926  3718  2238
# 24      1,054.11  287568      357    926  3718  2238
# 42      1,420.68  287568      357    926  3718  2238
# 14      1,143.46  287568      357    926  3718  2238
# 6       1,227.76  287568      357    926  3718  2238
# 41      1,195.90  287568      357    926  3718  2238
# 8         872.28  287568      357    926  3718  2238
# 28      1,402.31  287568      357    926  3718  2238
# 15        926.35  287568      357    926  3718  2238
# 36      1,125.27  287568      357    926  3718  2238
# 29      1,090.21  287568      357    926  3718  2238
# 2       1,026.31  287568      357    926  3718  2238
# 37      1,875.66  287568      357    926  3718  2238
# 35      1,125.27  287568      357    926  3718  2238
# 4         900.24  287568      357    926  3718  2238
# 43        963.19  287568      357    926  3718  2238
# 32      1,220.24  287568      357    926  3718  2238

# %%
Top_five=sort_WeeklySales[['Weekly_Sales', 'Store']][0:5:].reset_index(drop=True)
Top_five
#agrupar en semanas las 5 tiendas con mas ventas
# Out:
#     Weekly_Sales  Store
# 0 301,397,792.46     20
# 1 299,543,953.38      4
# 2 288,999,911.34     14
# 3 286,517,703.80     13
# 4 275,382,440.98      2

# %%
group=df.groupby("Year").sum("Weekly_Sales")
group.reset_index(level=0, inplace=True)
group["Weekly_Sales"]=(group["Weekly_Sales"])
group
#agrupamiento por año
# Out:
#    Year  Store     Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0  2010  49680 2,288,886,120.41           180   130,176.63    6,099.34
# 1  2011  53820 2,448,200,007.35           180   137,588.56    8,334.88
# 2  2012  44505 2,000,132,859.35            90   122,606.25    7,178.42
#
#          CPI  Unemployment  Quarter  Month   Week    Day
# 0 363,099.85     18,344.26     5715  15120  60750  34155
# 1 401,416.98     18,911.96     5940  15255  61110  36495
# 2 339,590.14     14,218.31     4410  11295  45450  30060

# %%
#con este script se pide a Python agrupar por Quarter
group=df.groupby("Quarter").sum("Weekly_Sales")
group.reset_index(level=0, inplace=True)
group["Weekly_Sales"]=(group["Weekly_Sales"])
group
#agrupa por cuartos
# Out:
#    Quarter  Store     Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0        1  34155 1,501,938,357.51             0    78,120.10    4,928.01
# 1        2  40365 1,826,038,445.58             0   110,697.65    6,045.35
# 2        3  39330 1,748,077,899.54            90   122,241.53    5,781.35
# 3        4  34155 1,661,164,284.48           360    79,312.16    4,857.92
#
#          CPI  Unemployment     Year  Month   Week    Day
# 0 254,578.11     11,918.73  2986470   3060  10080  22860
# 1 301,045.76     14,055.84  3529305   8685  33795  26865
# 2 293,952.91     13,574.42  3438810  13680  56070  28440
# 3 254,530.18     11,925.55  2985975  16245  67365  22545

# %%
df.set_index('Store')
#la tienda como index
# Out:
#             Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price    CPI  \
# Store
# 1     2010-05-02  1,643,690.90             0        42.31        2.57 211.10
# 1     2010-12-02  1,641,957.44             1        38.51        2.55 211.24
# 1     2010-02-19  1,611,968.17             0        39.93        2.51 211.29
# 1     2010-02-26  1,409,727.59             0        46.63        2.56 211.32
# 1     2010-05-03  1,554,806.68             0        46.50        2.62 211.35
# ...          ...           ...           ...          ...         ...    ...
# 45    2012-09-28    713,173.95             0        64.88        4.00 192.01
# 45    2012-05-10    733,455.07             0        64.89        3.98 192.17
# 45    2012-12-10    734,464.36             0        54.47        4.00 192.33
# 45    2012-10-19    718,125.53             0        56.47        3.97 192.33
# 45    2012-10-26    760,281.43             0        58.85        3.88 192.31
#
#        Unemployment  Year  Quarter  Month  Week  Day
# Store
# 1              8.11  2010        2      5    17    2
# 1              8.11  2010        4     12    48    2
# 1              8.11  2010        1      2     7   19
# 1              8.11  2010        1      2     8   26
# 1              8.11  2010        2      5    18    3
# ...             ...   ...      ...    ...   ...  ...
# 45             8.68  2012        3      9    39   28
# 45             8.67  2012        2      5    19   10
# 45             8.67  2012        4     12    50   10
# 45             8.67  2012        4     10    42   19
# 45             8.67  2012        4     10    43   26
#
# [6435 rows x 12 columns]

# %%
#con este script se pide a Python graficar las ventas por año y por mes
plt.figure(figsize=(20,8))
sns.lineplot(data=df, x='Month', y='Weekly_Sales', hue='Year', palette='tab10')
sns.set_style('whitegrid')
sns.despine(left=True, offset=20, trim=True)
plt.show()

# %%
# Sales for second and third quarter in 2012
Q2_sales = df[(df['Date'] >= '2012-04-01') & (df['Date'] <= '2012-06-30')].groupby('Store')['Weekly_Sales'].sum()
Q3_sales = df[(df['Date'] >= '2012-07-01') & (df['Date'] <= '2012-09-30')].groupby('Store')['Weekly_Sales'].sum()

# Plotting the difference between sales for second and third quarterly
plt.figure(figsize=(20,8))
Q2_sales.plot(ax=Q3_sales.plot(kind ='bar'),kind='bar',color='g',alpha=0.2,legend=True)
plt.legend(["Q3' 2012", "Q2' 2012"])

# %%
Q2_sales= df[(df['Date'] >= '2012-04-01') & (df['Date'] <= '2012-06-30')].groupby('Store')['Weekly_Sales'].sum()
Q3_sales= df[(df['Date'] >= '2012-07-01') & (df['Date'] <= '2012-09-30')].groupby('Store')['Weekly_Sales'].sum()
quarterly_growth_rate = ((Q3_sales - Q2_sales )/Q2_sales)*100
quarterly_growth_rate.sort_values(ascending=False).head()
# Out:
# Store
# 16   -2.79
# 7    -3.82
# 35   -4.66
# 26   -6.06
# 39   -6.40
# Name: Weekly_Sales, dtype: float64

# %%
plt.figure(figsize=(20,8))
quarterly_growth_rate.sort_values(ascending=False).plot(kind='bar')

# %%
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-05-02  1,643,690.90             0        42.31        2.57
# 1         1 2010-12-02  1,641,957.44             1        38.51        2.55
# 2         1 2010-02-19  1,611,968.17             0        39.93        2.51
# 3         1 2010-02-26  1,409,727.59             0        46.63        2.56
# 4         1 2010-05-03  1,554,806.68             0        46.50        2.62
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28    713,173.95             0        64.88        4.00
# 6431     45 2012-05-10    733,455.07             0        64.89        3.98
# 6432     45 2012-12-10    734,464.36             0        54.47        4.00
# 6433     45 2012-10-19    718,125.53             0        56.47        3.97
# 6434     45 2012-10-26    760,281.43             0        58.85        3.88
#
#         CPI  Unemployment  Year  Quarter  Month  Week  Day
# 0    211.10          8.11  2010        2      5    17    2
# 1    211.24          8.11  2010        4     12    48    2
# 2    211.29          8.11  2010        1      2     7   19
# 3    211.32          8.11  2010        1      2     8   26
# 4    211.35          8.11  2010        2      5    18    3
# ...     ...           ...   ...      ...    ...   ...  ...
# 6430 192.01          8.68  2012        3      9    39   28
# 6431 192.17          8.67  2012        2      5    19   10
# 6432 192.33          8.67  2012        4     12    50   10
# 6433 192.33          8.67  2012        4     10    42   19
# 6434 192.31          8.67  2012        4     10    43   26
#
# [6435 rows x 13 columns]

# %% [markdown]
# # Preparación de los datos

# %%
df_prediction=df.dropna()

# %%
df_agrupada=df_prediction.groupby(['Date','Store','CPI'])['Weekly_Sales'].sum().reset_index()

# %%
Store1=df_agrupada[(df_agrupada.Store==1)]
steps=-1

# %%
df_prediction2=Store1.copy()

# %%
df_prediction2['Ventas_reales']=df_prediction2['Weekly_Sales'].shift(steps)
df_prediction2=df_prediction2.dropna()
# Se realiza una segunda columna que representara las ventas, nos servira de prediccion

# %%
df_prediction2.index=df_prediction2['Date']

# %%
df_prediction2['Date'] =pd.to_datetime(df_prediction2['Date'])

# %%
X=df_prediction2[['Store','CPI','Weekly_Sales']]
y=df_prediction2[['Ventas_reales']]

# %%
train_size=int(len(Store1) *0.8)
test_size = int(len(Store1)) - train_size
train_X, train_y = X[:train_size].dropna(), y[:train_size].dropna()
test_X, test_y = X[train_size:].dropna(), y[train_size:].dropna()

# %%
import statsmodels.api as sm
seas_d=sm.tsa.seasonal_decompose(X['Weekly_Sales'],model='add');
fig=seas_d.plot()
fig.set_figheight(4)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-185-f1fd7f762183> in <module>
#       1 import statsmodels.api as sm
# ----> 2 seas_d=sm.tsa.seasonal_decompose(X['Weekly_Sales'],model='add');
#       3 fig=seas_d.plot()
#       4 fig.set_figheight(4)
#       5 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/seasonal.py in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     158         else:
#     159             raise ValueError(
# --> 160                 "You must specify a period or x must be a pandas object with "
#     161                 "a PeriodIndex or a DatetimeIndex with a freq not set to None"
#     162             )
#
# ValueError: You must specify a period or x must be a pandas object with a PeriodIndex or a DatetimeIndex with a freq not set to None

# %% [markdown]
# Split del modelo

# %% [markdown]
# #AutoArima

# %%
model_auto = auto_arima (train_y,
                         exogenous=train_X,
                         start_p=1, start_q=1,
                         max_p=7, max_q=7,
                         d=1, max_d=7,
                         trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=3062.465, Time=0.12 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=3091.245, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=3081.775, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=3089.251, Time=0.02 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=3064.235, Time=0.13 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=3064.545, Time=0.14 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=3062.815, Time=0.11 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=3076.628, Time=0.05 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.23 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=3062.870, Time=0.06 sec
#
# Best model:  ARIMA(1,1,1)(0,0,0)[0] intercept
# Total fit time: 1.054 seconds

# %%
model_auto
# Out:
# ARIMA(order=(1, 1, 1), scoring_args={}, suppress_warnings=True)

# %%
model_auto.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  114
# Model:               SARIMAX(1, 1, 1)   Log Likelihood               -1527.232
# Date:                Fri, 04 Nov 2022   AIC                           3062.465
# Time:                        18:59:25   BIC                           3073.374
# Sample:                             0   HQIC                          3066.892
#                                 - 114
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   2037.4763   1039.698      1.960      0.050      -0.294    4075.247
# ar.L1          0.3227      0.067      4.838      0.000       0.192       0.453
# ma.L1         -0.9664      0.041    -23.442      0.000      -1.047      -0.886
# sigma2      3.127e+10      0.000   2.82e+14      0.000    3.13e+10    3.13e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.21   Jarque-Bera (JB):                49.60
# Prob(Q):                              0.65   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.53   Skew:                             1.02
# Prob(H) (two-sided):                  0.19   Kurtosis:                         5.53
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 6.67e+29. Standard errors may be unstable.
# """

# %% [markdown]
# #SARIMAX

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
model_SA = SARIMAX(train_y,seasonal_order=(0,1,0,52),exog=train_X, order=(0,1,2),
                   enforce_invertibility=False, enforce_stationarity=False)

# %%
results= model_SA.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                       Ventas_reales   No. Observations:                  114
# Model:             SARIMAX(0, 1, 2)x(0, 1, [], 52)   Log Likelihood                -777.562
# Date:                             Fri, 04 Nov 2022   AIC                           1567.125
# Time:                                     18:59:34   BIC                           1579.488
# Sample:                                          0   HQIC                          1571.940
#                                              - 114
# Covariance Type:                               opg
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Store        -4.337e-07     32.953  -1.32e-08      1.000     -64.587      64.587
# CPI           1.833e+04   8920.959      2.055      0.040     843.931    3.58e+04
# Weekly_Sales    -0.2805      0.463     -0.606      0.545      -1.188       0.627
# ma.L1           -0.3525      0.400     -0.881      0.378      -1.137       0.432
# ma.L2           -0.1874      0.343     -0.547      0.584      -0.859       0.484
# sigma2        2.176e+10      0.020   1.09e+12      0.000    2.18e+10    2.18e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.68   Jarque-Bera (JB):                42.29
# Prob(Q):                              0.41   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.10   Skew:                             0.83
# Prob(H) (two-sided):                  0.84   Kurtosis:                         6.84
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.45e+27. Standard errors may be unstable.
# """

# %% [markdown]
# # Predicción

# %%
# %matplotlib inline

# %%
from pandas import DataFrame
import matplotlib.patches as mpatches
import statsmodels.api as sm
import pandas as pd

# %%
seas_d=sm.tsa.seasonal_decompose(X['Weekly_Sales'],model='add');
fig=seas_d.plot()
fig.set_figheight(4)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-166-dc0e6ddbc254> in <module>
# ----> 1 seas_d=sm.tsa.seasonal_decompose(X['Weekly_Sales'],model='add');
#       2 fig=seas_d.plot()
#       3 fig.set_figheight(4)
#       4 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/seasonal.py in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     158         else:
#     159             raise ValueError(
# --> 160                 "You must specify a period or x must be a pandas object with "
#     161                 "a PeriodIndex or a DatetimeIndex with a freq not set to None"
#     162             )
#
# ValueError: You must specify a period or x must be a pandas object with a PeriodIndex or a DatetimeIndex with a freq not set to None

# %%
descomposicion = sm.tsa.seasonal_decompose(['Ventas_reales'],
                                                  model='additive')  
fig = descomposicion.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-157-571346b5f415> in <module>
#       1 descomposicion = sm.tsa.seasonal_decompose(['Ventas_reales'],
# ----> 2                                                   model='additive')
#       3 fig = descomposicion.plot()
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/seasonal.py in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     140         pfreq = getattr(getattr(x, "index", None), "inferred_freq", None)
#     141
# --> 142     x = array_like(x, "x", maxdim=2)
#     143     nobs = len(x)
#     144
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/validation/validation.py in array_like(obj, name, dtype, ndim, maxdim, shape, order, contiguous, optional)
#     133     if optional and obj is None:
#     134         return None
# --> 135     arr = np.asarray(obj, dtype=dtype, order=order)
#     136     if maxdim is not None:
#     137         if arr.ndim > maxdim:
#
# ValueError: could not convert string to float: 'Ventas_reales'

# %%
residuals = DataFrame(results.resid)
cycle, trend = sm.tsa.filters.hpfilter(residuals)
residuals.plot()
plt.xticks(rotation=90)
plt.show()
residuals.plot(kind='kde')
plt.show()
print(residuals.describe())
# Out:
#                 0
# count      142.00
# mean   -24,459.48
# std    156,057.26
# min   -399,950.77
# 25%   -114,718.56
# 50%    -40,892.80
# 75%     47,068.52
# max    716,837.40

# %%
predictions = list()
plt.plot(df_test)
plt.plot(predictions, color='red')
red_patch = mpatches.Patch(color='red', label='The predicted data')
blue_patch = mpatches.Patch(color='blue', label='The expected data')
plt.legend(handles=[blue_patch,red_patch])
plt.show()

# %%
pd.DataFrame(y.iloc[size:, :])
predictions=pd.DataFrame(predictions)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-122-216e08fae4f7> in <module>
#       1 pd.DataFrame(y.iloc[size:, :])
# ----> 2 predictions=pd.DataFrame(predictions)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     728         else:
#     729             if index is None or columns is None:
# --> 730                 raise ValueError("DataFrame constructor not properly called!")
#     731
#     732             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# ValueError: DataFrame constructor not properly called!

# %%
predictions=pd.DataFrame(predictions)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-121-ad37bd724f27> in <module>
# ----> 1 predictions=pd.DataFrame(predictions)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     728         else:
#     729             if index is None or columns is None:
# --> 730                 raise ValueError("DataFrame constructor not properly called!")
#     731
#     732             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# ValueError: DataFrame constructor not properly called!

# %%
df_auto_pred = pd.DataFrame (model_SA.predict(n_periods =len(df_test[start_date:end_date])),index = df_test.index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-109-d344cccbdd8d> in <module>
# ----> 1 df_auto_pred = pd.DataFrame (model_SA.predict(n_periods =len(df_test[start_date:end_date])),index = df_test.index)
#
# NameError: name 'start_date' is not defined

# %%
# Out:
# count                     143
# unique                    143
# top       2010-01-10 00:00:00
# freq                        1
# first     2010-01-10 00:00:00
# last      2012-12-10 00:00:00
# Name: Date, dtype: object

# %%
y_pred = model_auto(n_periods=len(df_test['Weekly_Sales']))
y_pred = pd.DataFrame(y_pred,index = df_test['Weekly_Sales'].index,columns=['Prediction'])
plt.figure(figsize=(20,6))
plt.title('Prediction of Weekly Sales Using Auto-ARIMA', fontsize=20)
plt.plot(df_train['Weekly_Sales'], label='Train')
plt.plot(df_test['Weekly_Sales'], label='Test')
plt.plot(y_pred, label='Prediction of ARIMA')
plt.legend(loc='best')
plt.xlabel('Date', fontsize=14)
plt.ylabel('Weekly Sales', fontsize=14)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-112-c82827211601> in <module>
# ----> 1 y_pred = model_auto(n_periods=len(df_test['Weekly_Sales']))
#       2 y_pred = pd.DataFrame(y_pred,index = df_test['Weekly_Sales'].index,columns=['Prediction'])
#       3 plt.figure(figsize=(20,6))
#       4 plt.title('Prediction of Weekly Sales Using Auto-ARIMA', fontsize=20)
#       5 plt.plot(df_train['Weekly_Sales'], label='Train')
#
# TypeError: 'ARIMA' object is not callable

# %%
df_auto_pred = pd.Dataframe(model_SA.predict(n_periods = df_test[start_date:end_date]),
                            exogenous = df_test[[]][],
                            index=df_test[].index)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-bbc7f90b8425> in <module>
# ----> 1 df_auto_pred = model_SA.predict(n_periods = len(start=df_train,end=df_train+df_test+(steps)-1,exog=test_X))
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/arraylike.py in __add__(self, other)
#      90     @unpack_zerodim_and_defer("__add__")
#      91     def __add__(self, other):
# ---> 92         return self._arith_method(other, operator.add)
#      93
#      94     @unpack_zerodim_and_defer("__radd__")
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in _arith_method(self, other, op)
#    6864         self, other = ops.align_method_FRAME(self, other, axis, flex=True, level=None)
#    6865
# -> 6866         new_data = self._dispatch_frame_op(other, op, axis=axis)
#    6867         return self._construct_result(new_data)
#    6868
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in _dispatch_frame_op(self, right, func, axis)
#    6911                     # "BlockManager"
#    6912                     right._mgr,  # type: ignore[arg-type]
# -> 6913                     array_op,
#    6914                 )
#    6915             return type(self)(bm)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in operate_blockwise(self, other, array_op)
#    1301         Apply array_op blockwise with another (aligned) BlockManager.
#    1302         """
# -> 1303         return operate_blockwise(self, other, array_op)
#    1304
#    1305     def _equal_values(self: BlockManager, other: BlockManager) -> bool:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/ops.py in operate_blockwise(left, right, array_op)
#      55     res_blks: list[Block] = []
#      56     for lvals, rvals, locs, left_ea, right_ea, rblk in _iter_block_pairs(left, right):
# ---> 57         res_values = array_op(lvals, rvals)
#      58         if left_ea and not right_ea and hasattr(res_values, "reshape"):
#      59             res_values = res_values.reshape(1, -1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/array_ops.py in arithmetic_op(left, right, op)
#     216         # Timedelta/Timestamp and other custom scalars are included in the check
#     217         # because numexpr will fail on it, see GH#31457
# --> 218         res_values = op(left, right)
#     219     else:
#     220         # TODO we should handle EAs consistently and move this check before the if/else
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/arrays/datetimelike.py in __add__(self, other)
#    1277         elif is_datetime64_dtype(other_dtype) or is_datetime64tz_dtype(other_dtype):
#    1278             # DatetimeIndex, ndarray[datetime64]
# -> 1279             return self._add_datetime_arraylike(other)
#    1280         elif is_integer_dtype(other_dtype):
#    1281             if not is_period_dtype(self.dtype):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/arrays/datetimelike.py in _add_datetimelike_scalar(self, other)
#    1050     def _add_datetimelike_scalar(self, other):
#    1051         # Overridden by TimedeltaArray
# -> 1052         raise TypeError(f"cannot add {type(self).__name__} and {type(other).__name__}")
#    1053
#    1054     _add_datetime_arraylike = _add_datetimelike_scalar
#
# TypeError: cannot add DatetimeArray and DatetimeArray

# %%
model_auto2 = auto_arima (df_train.Weekly_Sales, m= 5, max_order = None, max_p = 7, max_q=7, max_d=2, max_P=4, max_Q=4, max_D=2, maxiter=50, alpha=0.05, n_jobs=-1, trend='ct', information_criterion='oob', out_of_sample_size= int(len(df)*0.2))

# %%
model_auto2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                 5148
# Model:             SARIMAX(1, 1, 0)x(2, 0, [1], 5)   Log Likelihood              -69654.275
# Date:                             Thu, 03 Nov 2022   AIC                         139322.549
# Time:                                     19:25:06   BIC                         139368.373
# Sample:                                          0   HQIC                        139338.586
#                                             - 5148
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   -916.1180   1.16e+04     -0.079      0.937   -2.36e+04    2.17e+04
# drift          0.4853      4.315      0.112      0.910      -7.972       8.943
# ar.L1         -0.3270      0.008    -40.677      0.000      -0.343      -0.311
# ar.S.L5       -1.1391      0.034    -33.250      0.000      -1.206      -1.072
# ar.S.L10      -0.2431      0.011    -21.140      0.000      -0.266      -0.221
# ma.S.L5        0.9187      0.034     27.160      0.000       0.852       0.985
# sigma2      3.993e+10   6.01e-05   6.65e+14      0.000    3.99e+10    3.99e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                  13.45   Jarque-Bera (JB):             84662.50
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.55   Skew:                            -0.47
# Prob(H) (two-sided):                  0.00   Kurtosis:                        22.85
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.72e+33. Standard errors may be unstable.
# """

# %% [markdown]
# #Predicciones

# %%
model_auto = auto_arima (df_train.Weekly_Sales)

# %%
df_auto_pred = pd.DataFrame (model_auto.predict(n_periods =len(df_test[start_date:end_date])),index = df_test.index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-142-a359a5aaabe4> in <module>
# ----> 1 df_auto_pred = pd.DataFrame (model_auto.predict(n_periods =len(df_test[start_dat:end_date])),index = df_test.index)
#
# NameError: name 'start_dat' is not defined

# %%
df_auto_pred.plot(figsize=(20,5), color = "red")
df_test.Weekly_Sales.plot(color = "blue")
plt.show()

# %% [markdown]
# ELISA

# %%
df.set_index("Date", inplace=True)
#se establece la fecha como índice

# %%
df.head()
#Encabezados con el Date como índice
# Out:
#             Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price    CPI  \
# Date
# 2010-05-02      1  1,643,690.90             0        42.31        2.57 211.10
# 2010-12-02      1  1,641,957.44             1        38.51        2.55 211.24
# 2010-02-19      1  1,611,968.17             0        39.93        2.51 211.29
# 2010-02-26      1  1,409,727.59             0        46.63        2.56 211.32
# 2010-05-03      1  1,554,806.68             0        46.50        2.62 211.35
#
#             Unemployment  Year  Quarter  Month  Week  Day
# Date
# 2010-05-02          8.11  2010        2      5    17    2
# 2010-12-02          8.11  2010        4     12    48    2
# 2010-02-19          8.11  2010        1      2     7   19
# 2010-02-26          8.11  2010        1      2     8   26
# 2010-05-03          8.11  2010        2      5    18    3

# %%
df_comp=df_comp.asfreq("w")

# %%
df_comp.isna().sum()

# %%
df_comp ["WS"] = df_comp.Weekly_Sales

# %%
df_comp.describe()

# %% [markdown]
# SPLIT

# %%
size = int(len(df_comp)*0.8)
#se hace un conjunto de entrenamiento dividiendo al 0.8 de la base total

# %%
size
#se pide el tamaño del conjunto de 0.8

# %%
df_train=df_comp.iloc[:size]

# %%
df_train

# %%
df_test = df_comp.iloc[size:]

# %%
df_test

# %%
df_train.tail()

# %%
df_test.tail()

# %%
import matplotlib.pyplot as plt

# %%
df_train.WS.plot(figsize=(20,5))
#plt.ylim(3,4)
#plt.title("WSa", size = 24)
#plt.show()

# %%
df_train["Day"]= pd.Date(df_train['Date']).day
df_train["Week"]= pd.Date(df_train['Date']).week
df_train['Month'] = pd.Date(df_train['Date']).month
df_train['Year'] = pd.Date(df_train['Date']).year
df

# %% [markdown]
# df_comp ["WS"] = df_comp.Weekly_Sales

# %%
infer_datetime_format=True
df_comp["Day"]= pd.DatetimeIndex(df_comp['Date']).day
df_comp["Week"]= pd.DatetimeIndex(df_comp['Date']).week
df_comp['Month'] = pd.DatetimeIndex(df_comp['Date']).month
df_comp['Year'] = pd.DatetimeIndex(df_comp['Date']).year
df

# %%
df_comp.tail (20)
# ver los últimos registros

# %%
df_comp.isna()
#nulos?

# %%
df_comp.isnull().sum()
#identificar valores nulos

# %%
df_comp.Weekly_Sales.isna().sum()
#nulos en ventas semanales

# %%
data_sort=df_comp.sort_values("Date")
data_sort
#se ordenan los datos en relación a las fechas

# %%
#con la funcion groupby se inidca al sistema agrupar por tienda y por semana
group=df_comp.groupby("Store").sum("Weekly_Sales")

# %%
group.reset_index(level=0, inplace=True)
group
#se cambia el index

# %%
std = df_comp.groupby('Store')['Weekly_Sales'].std()
std = pd.DataFrame(std)
std_sort=std.sort_values('Weekly_Sales', ascending=False)
std_sort
#se obtiene la desviación

# %% [markdown]
# # Análisis exploratorio

# %%
df_comp.Weekly_Sales.plot(figsize=(20,5),title = "Weekly_Sales")
plt.show()
#se analizan las ventas semanales de forma gráfica

# %%
df_comp.Temperature.plot(figsize=(20,5),title = "Temperature")
plt.show()

# %%
df_comp.Weekly_Sales.plot(figsize=(20,5),title = "Weekly_Sales")
df_comp.Fuel_Price.plot(figsize=(20,5), title = "Fuel_Price")
plt.title("weekly sales vs fuel price")
plt.show()

# %%
df_comp.Weekly_Sales.plot(figsize=(20,5),title = "Weekly_Sales")
df_comp.Temperature.plot(figsize=(20,5), title = "Temperature")
plt.title("weekly sales vs temperature")
plt.show()

# %%
import scipy.stats

# %%
scipy.stats.probplot(df_comp.Weekly_Sales, plot = plt)
plt.title ("QQ Plot", size = 24)
plt.show()
#qq PLOT de los quartiles, no se distribuye normalmente

# %%
df_comp.describe()

# %%
total_sales= df_comp.groupby('Store')['Weekly_Sales'].sum().sort_values() 
plt.figure(figsize=(15,7))
plt.ticklabel_format( style='plain', axis='y')
plt.title('Ventas por cada tienda')
plt.xlabel('Tienda')
plt.ylabel('Ventas totales')
total_sales.plot(kind='bar');
# tienda con el maximo de ventas suma de las ventas semanales por tienda. Tienda X, Ventas Y

# %%
df_std = pd.DataFrame(df_comp.groupby('Store')['Weekly_Sales'].std().sort_values(ascending=False))
df_std.head(1).index[0] , df_std.head(1).Weekly_Sales[df_std.head(1).index[0]] 
# tienda con más desviacion estandar. Se agrupo por tienda, se obtuvo la desviacion

# %%
coef = pd.DataFrame(df.groupby('Store')['Weekly_Sales'].std() / df.groupby('Store')['Weekly_Sales'].mean()*100)
coef.head
# Coeficiente de desviación medio

# %%
tercer_trimestre= df[(df['Date'] >= '2012-07-01') & (df['Date'] <= '2012-09-30')].groupby('Store')['Weekly_Sales'].sum().sort_values()
plt.figure(figsize=(15,7))
tercer_trimestre.plot(kind='bar',legend=True)
plt.ticklabel_format( style='plain', axis='y')
plt.legend(["3-Trimestre' 2012"]);
#Crecimiento tercer trimestre 2012 por tienda

# %%
Super_Bowl =['12-2-2010', '11-2-2011', '10-2-2012']
Día_del_trabajo =  ['10-9-2010', '9-9-2011', '7-9-2012']
Acción_de_gracias =  ['26-11-2010', '25-11-2011', '23-11-2012']
Navidad = ['31-12-2010', '30-12-2011', '28-12-2012']
#Definir días festivos

# %%
infer_datetime_format=True 
Ventas_Super_Bowl= (pd.DataFrame(df.loc[df.Date.isin(Super_Bowl)]))['Weekly_Sales'].mean()
Ventas_Día_del_trabajo = (pd.DataFrame(df.loc[df.Date.isin(Día_del_trabajo)]))['Weekly_Sales'].mean()
Ventas_Acción_de_gracias = (pd.DataFrame(df.loc[df.Date.isin(Acción_de_gracias)]))['Weekly_Sales'].mean()
Ventas_Navidad = (pd.DataFrame(df.loc[df.Date.isin(Navidad)]))['Weekly_Sales'].mean()
Ventas_Super_Bowl,Ventas_Día_del_trabajo,Ventas_Acción_de_gracias,Ventas_Navidad

#Medias de ventas en días festivos

# %%
Ventas_no_festivos = df[df['Holiday_Flag'] == 0 ]['Weekly_Sales'].mean()
Ventas_no_festivos
# Medias en días no festivos

# %%
Promedio_ventas = {'Ventas_Super_Bowl' : Ventas_Super_Bowl,
              'Ventas_Día_del_trabajo': Ventas_Día_del_trabajo,
              'Ventas_Acción_de_gracias':Ventas_Acción_de_gracias,
              'Ventas_Navidad': Ventas_Navidad,
              'Ventas_no_festivos': Ventas_no_festivos}
Promedio_ventas

# %%
df["Year"].unique()
#ventas en a;os

# %%
plt.figure(figsize=(15,7))
plt.scatter(df[df.Year==2010]["Month"],df[df.Year==2010]["Weekly_Sales"])
plt.xlabel("Months")
plt.ylabel("Weekly Sales")
plt.title("Monthly view of sales in 2010")
plt.show()

plt.figure(figsize=(15,7))
plt.scatter(df[df.Year==2011]["Month"],df[df.Year==2011]["Weekly_Sales"])
plt.xlabel("Months")
plt.ylabel("Weekly Sales")
plt.title("Monthly view of sales in 2011")
plt.show()

plt.figure(figsize=(15,7))
plt.scatter(df[df.Year==2012]["Month"],df[df.Year==2012]["Weekly_Sales"])
plt.xlabel("Months")
plt.ylabel("Weekly Sales")
plt.title("Monthly view of sales in 2012")
plt.show()
# Ventas mensuales por año

# %%
ventas_mensuales = pd.pivot_table(df, values = "Weekly_Sales", columns = "Year", index = "Month")
ventas_mensuales.plot()

# %% [markdown]
# # Quitar valores fuera de rango

# %%
fig, axis = plt.subplots(4,figsize=(16,16))
X = df[['Temperature','Fuel_Price','CPI','Unemployment']]
for i,column in enumerate(X):
    sns.boxplot(df[column],ax=axis[i])
# Checamos valores atipicos

# %%
sns.scatterplot(data=df,x='Temperature', y='Weekly_Sales', hue = 'Year')
plt.axvline(x=10,color='r')

# %%
sns.scatterplot(data=df,x='Unemployment', y='Weekly_Sales', hue = 'Year')
plt.axvline(x=4.5,color='r')

# %%
df_limpia = df[(df['Unemployment']<10) & (df['Unemployment']>4.5) & (df['Temperature']>10)]
# Quitamos valores atipicos en una nueva función

# %%
fig, axis = plt.subplots(4,figsize=(16,16))
X = df_limpia[['Temperature','Fuel_Price','CPI','Unemployment']]
for i,column in enumerate(X):
    sns.boxplot(df_limpia[column],ax=axis[i])
# Verificamos ya no tener valores atipicos

# %%
plt.figure(figsize = (12,12))
sns.heatmap(df_limpia.corr().abs())    # To see the correlations
plt.show()

# %% [markdown]
# # Modelos

# %%
from pmdarima import auto_arima

# %%
df_arima=df
df_arima=df_arima.set_index('Date')

# %%
plt.figure(figsize=(16,9))
df_arima['Weekly_Sales'].plot()
plt.show()

# %%
df_arimamonth = df_arima.resample('M').mean()

# %%
plt.figure(figsize=(16,6))
df_arimamonth['Weekly_Sales'].plot()
plt.title('Average Sales - Weekly')
plt.show()

# %%
train_data = df_arimamonth[:int(0.7*(len(df_arimamonth)))] 
test_data = df_arimamonth[int(0.7*(len(df_arimamonth))):]

print('Train:', train_data.shape)
print('Test:', test_data.shape)

# %%
train_data['Weekly_Sales'].plot(figsize=(20,8), title= 'Weekly_Sales', fontsize=14)
test_data['Weekly_Sales'].plot(figsize=(20,8), title= 'Weekly_Sales', fontsize=14)
plt.show()

# %%
from pmdarima.arima import ADFTest
adf_test = ADFTest(alpha = 0.05)
adf_test.should_diff (df_arimamonth['Weekly_Sales'])

# %%
model_auto_arima = auto_arima(train_data['Weekly_Sales'], trace=True,start_p=0, start_q=0, start_P=0, start_Q=0,
                  max_p=20, max_q=20, max_P=20, max_Q=20, seasonal=True,maxiter=200,
                  information_criterion='aic',stepwise=False, suppress_warnings=True, D=2, max_D=0, d=1, 
                  error_action='ignore',approximation = False)
model_auto_arima.fit(train_data['Weekly_Sales'])

# %%
model_auto_arima.summary()

# %%
y_pred = model_auto_arima.predict(n_periods=len(test_data['Weekly_Sales']))
y_pred = pd.DataFrame(y_pred,index = test_data['Weekly_Sales'].index,columns=['Prediction'])
plt.figure(figsize=(20,6))
plt.title('Prediction of Weekly Sales Using Auto-ARIMA', fontsize=20)
plt.plot(train_data['Weekly_Sales'], label='Train')
plt.plot(test_data['Weekly_Sales'], label='Test')
plt.plot(y_pred, label='Prediction of ARIMA')
plt.legend(loc='best')
plt.xlabel('Date', fontsize=14)
plt.ylabel('Weekly Sales', fontsize=14)
plt.show()

# %%
train = df_limpia['Weekly_Sales']
test = df_limpia['Weekly_Sales']
plt.plot(train)
plt.plot(test)
#plt.plot(test)

# %%
plt.figure(figsize=(50,6))
df_limpia['Weekly_Sales'].plot()

# %%
model_auto_arima = auto_arima(train_data_diff, trace=True,start_p=0, start_q=0, start_P=0, start_Q=0,
                  max_p=20, max_q=20, max_P=20, max_Q=20, seasonal=True,maxiter=200,
                  information_criterion='aic',stepwise=False, suppress_warnings=True, D=1, max_D=10,
                  error_action='ignore',approximation = False)
model_auto_arima.fit(train_data_diff)

# %%
X = df_limpia[['Store','Fuel_Price','CPI','Unemployment','Day','Month','Year']]
y = df_limpia['Weekly_Sales']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 100)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train,y_train)

# %%
model.coef_

# %%
X.mean()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.scatter(model.predict(X_test),y_test)
plt.xlabel('Model Predictions')
plt.ylabel('True Value')

plt.show()

# %%
from scipy.stats import pearsonr

pearsonr(model.predict(X_test),y_test)

# %%
from sklearn import metrics

# %%
print('Linear Regression:')
print()
reg = LinearRegression()
reg.fit(X_train, y_train)
y_pred = reg.predict(X_test)
print('Accuracy:',reg.score(X_train, y_train)*100)
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('R Squared:',metrics.r2_score(y_test, y_pred))

# %%
from sklearn.ensemble import RandomForestRegressor
print('Random Forest Regressor:')
print()
rfr = RandomForestRegressor()        
rfr.fit(X_train,y_train)
y_pred = rfr.predict(X_test)
print('Accuracy:',rfr.score(X_test, y_test)*100)
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('R Squared:',metrics.r2_score(y_test, y_pred))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.scatter(y_pred,y_test)
plt.xlabel('Model Predictions')
plt.ylabel('True Value')

plt.show()

# %%
pearsonr(y_pred,y_test)
